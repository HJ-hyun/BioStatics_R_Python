# %%
import rpy2.robjects as robjects 
from rpy2.robjects.packages import importr  
import rpy2.rinterface as ri
biobase = importr('Biobase')

# %%
r = robjects.r 
g = robjects.globalenv 
dim = r['dim']

# %%
r('data("sample.ExpressionSet")')
# Out:
# R object with classes: ('character',) mapped to:
# <StrVector - Python:0x2b1b88d5dcc8 / R:0x2b1b385230f0>
# ['sample.ExpressionSet']

# %%
sample_ExpressionSet = r['sample.ExpressionSet']

# %%
eset = sample_ExpressionSet

# %%
print(eset)
# Out:
# ExpressionSet (storageMode: lockedEnvironment)
# assayData: 500 features, 26 samples
#   element names: exprs, se.exprs
# protocolData: none
# phenoData
#   sampleNames: A B ... Z (26 total)
#   varLabels: sex type score
#   varMetadata: labelDescription
# featureData: none
# experimentData: use 'experimentData(object)'
# Annotation: hgu95av2

# %%
print(dim(eset))
# Out:
# Features  Samples
#      500       26

# %%
r('expression_data <- exprs(sample.ExpressionSet)')
r('expression_data_df <- as.data.frame(expression_data)')
# Out:
# R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x2b1b88eb1dc8 / R:0x2b1b8a186470>
# [FloatVector, FloatVector, FloatVector, FloatVector, ..., FloatVector, FloatVector, FloatVector, FloatVector]
#   A: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x2b1b88eb1f48 / R:0x2b1b8a814040>
# [192.742000, 97.137000, 45.819200, 22.544500, ..., 446.512000, 22.464100, 299.434000, 253.692000]
#   B: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x2b1b88eb1388 / R:0x2b1b8a8187d0>
# [85.753300, 126.196000, 8.831350, 3.600930, ..., 271.494000, 23.458900, 233.138000, 183.306000]
#   C: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x2b1b88eb1248 / R:0x2b1b8a81cf60>
# ...

# %%
expression_df = r['expression_data_df']

# %%
rownames = r['rownames']

# %%
print("rows: "+ str(len(exprs_data)) + ", columns: " + str(len(exprs_data[0])))
# Out:
# rows: 500, columns: 26

# %%
feature_data = r('fData(sample.ExpressionSet)')
pheno_data = r('pData(sample.ExpressionSet)')

# %%
pheno_data
# Out:
# R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x2b1b896bb888 / R:0x2b1b37ad3268>
# [FactorVector, FactorVector, FloatVector]
#   sex: <class 'rpy2.robjects.vectors.FactorVector'>
#   R object with classes: ('factor',) mapped to:
# <FactorVector - Python:0x2b1b8a98c908 / R:0x2b1b37bfe0b8>
# [Female, Male, Male, Male, ..., Male, Male, Female, Female]
#   type: <class 'rpy2.robjects.vectors.FactorVector'>
#   R object with classes: ('factor',) mapped to:
# <FactorVector - Python:0x2b1b8a98c6c8 / R:0x2b1b37bfe218>
# [Control, Case, Control, Case, ..., Control, Control, Case, Case]
#   score: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x2b1b8a98c4c8 / R:0x2b1b89e241c0>
# [0.750000, 0.400000, 0.730000, 0.420000, ..., 0.270000, 0.980000, 0.940000, 0.320000]

# %%
from rpy2.robjects import pandas2ri
import pandas as pd
pandas2ri.activate()
# Out:
# /home/users/hwangzi/tools/anaconda3/envs/study/lib/python3.6/site-packages/rpy2/robjects/pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex

# %%
pd_expression_df = pandas2ri.ri2py_dataframe(expression_df)

# %%
pd_expression_df.index = list(rownames(expression_df))

# %%
pd_expression_df
# Out:
#                         A          B         C         D          E         F  \
# AFFX-MurIL2_at   192.7420   85.75330  176.7570  135.5750   64.49390   76.3569
# AFFX-MurIL10_at   97.1370  126.19600   77.9216   93.3713   24.39860   85.5088
# AFFX-MurIL4_at    45.8192    8.83135   33.0632   28.7072    5.94492   28.2925
# AFFX-MurFAS_at    22.5445    3.60093   14.6883   12.3397   36.86630   11.2568
# AFFX-BioB-5_at    96.7875   30.43800   46.1271   70.9319   56.17440   42.6756
# ...                   ...        ...       ...       ...        ...       ...
# 31735_at          26.7016   33.15780   31.7113   36.6217   26.82840   38.9910
# 31736_at         446.5120  271.49400  304.8090  340.9780  356.12700  279.0150
# 31737_at          22.4641   23.45890   39.4170   25.7452   14.40320   27.1660
# 31738_at         299.4340  233.13800  355.2040  314.8180  238.68400  205.6970
# 31739_at         253.6920  183.30600  291.3850  270.7190  212.02500  225.3570
#
# ...

# %%
type(pd_expression_df)
# Out:
# pandas.core.frame.DataFrame
